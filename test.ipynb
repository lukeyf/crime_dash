# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

# %%
pd.DataFrame(counties['features'])
# Out:
#          type                                         properties  \
# 0     Feature  {'GEO_ID': '0500000US01001', 'STATE': '01', 'C...
# 1     Feature  {'GEO_ID': '0500000US01009', 'STATE': '01', 'C...
# 2     Feature  {'GEO_ID': '0500000US01017', 'STATE': '01', 'C...
# 3     Feature  {'GEO_ID': '0500000US01021', 'STATE': '01', 'C...
# 4     Feature  {'GEO_ID': '0500000US01033', 'STATE': '01', 'C...
# ...       ...                                                ...
# 3216  Feature  {'GEO_ID': '0500000US51001', 'STATE': '51', 'C...
# 3217  Feature  {'GEO_ID': '0500000US51021', 'STATE': '51', 'C...
# 3218  Feature  {'GEO_ID': '0500000US51027', 'STATE': '51', 'C...
# 3219  Feature  {'GEO_ID': '0500000US51037', 'STATE': '51', 'C...
# 3220  Feature  {'GEO_ID': '0500000US51041', 'STATE': '51', 'C...
#
#                                                geometry     id
# 0     {'type': 'Polygon', 'coordinates': [[[-86.4967...  01001
# 1     {'type': 'Polygon', 'coordinates': [[[-86.5777...  01009
# 2     {'type': 'Polygon', 'coordinates': [[[-85.1841...  01017
# 3     {'type': 'Polygon', 'coordinates': [[[-86.5173...  01021
# 4     {'type': 'Polygon', 'coordinates': [[[-88.1399...  01033
# ...                                                 ...    ...
# 3216  {'type': 'MultiPolygon', 'coordinates': [[[[-7...  51001
# 3217  {'type': 'Polygon', 'coordinates': [[[-81.2251...  51021
# 3218  {'type': 'Polygon', 'coordinates': [[[-81.9682...  51027
# 3219  {'type': 'Polygon', 'coordinates': [[[-78.4433...  51037
# 3220  {'type': 'Polygon', 'coordinates': [[[-77.8518...  51041
#
# [3221 rows x 4 columns]

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/fips-unemp-16.csv",
                   dtype={"fips": str})

df
# Out:
#        fips  unemp
# 0     01001    5.3
# 1     01003    5.4
# 2     01005    8.6
# 3     01007    6.6
# 4     01009    5.5
# ...     ...    ...
# 3214  72145   13.9
# 3215  72147   10.6
# 3216  72149   20.2
# 3217  72151   16.9
# 3218  72153   18.8
#
# [3219 rows x 2 columns]
